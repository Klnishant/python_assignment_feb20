# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# Input

# %% [markdown]
# ![app.py - workspace - code-server - Google Chrome 27-02-2023 12_18_20.png](attachment:86af6c49-7a29-4bf0-bdba-0c7dd77c6177.png)

# %% [markdown]
# Output

# %% [markdown]
# ![https___white-painter-ywfxy.pwskills.app_5000_postman_action - My Workspace 27-02-2023 12_32_56.png](attachment:cade6fe5-2d37-4eec-96f7-f4213aa158a6.png)
